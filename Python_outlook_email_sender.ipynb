# %%
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.To = 'paul.depellegars-malhortie@edhec.com'
mail.Subject = 'Market Recap | EMEA Rates forecasts'
mail.Body = 'Hi Team, please find attached the file for EMEA Rates...'
#mail.HTMLBody = '<h2>HTML Message body</h2>' #this field is optional

# To attach a file to the email (optional):
attachment  = ##
mail.Attachments.Add(attachment)

mail.Send()

# %%
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.To = 'paul.depellegars-malhortie@edhec.com'
mail.Subject = 'Market Recap | EMEA Rates forecasts'
mail.Body = 'Hi Team, please find attached the file for EMEA Rates...'


# Le corps du message en HTML
html = """
<!DOCTYPE html>
<html>
<head>
    <style>
        table {
            width: 100%;
            border-collapse: collapse;
        }
        table, th, td {
            border: 1px solid black;
        }
        th, td {
            padding: 10px;
            text-align: left;
        }
        th {
            background-color: #f2f2f2;
        }
    </style>
</head>
<body>

<h2>Tableau de 5 lignes et 5 colonnes</h2>

<table>
  <tr>
    <th>Rates</th>
    <th>UK</th>
    <th>USA</th>
    <th>Germany</th>
    <th>Italy</th>
  </tr>
  <tr>
    <td>6 months</td>
    <td>1 year</td>
    <td>2 year</td>
    <td>3 year</td>
    <td>10 year</td>
  </tr>
  <tr>
    <td>Cellule 2-1</td>
    <td>Cellule 2-2</td>
    <td>Cellule 2-3</td>
    <td>Cellule 2-4</td>
    <td>Cellule 2-5</td>
  </tr>
  <tr>
    <td>Cellule 3-1</td>
    <td>Cellule 3-2</td>
    <td>Cellule 3-3</td>
    <td>Cellule 3-4</td>
    <td>Cellule 3-5</td>
  </tr>
  <tr>
    <td>Cellule 4-1</td>
    <td>Cellule 4-2</td>
    <td>Cellule 4-3</td>
    <td>Cellule 4-4</td>
    <td>Cellule 4-5</td>
  </tr>
  <tr>
    <td>Cellule 5-1</td>
    <td>Cellule 5-2</td>
    <td>Cellule 5-3</td>
    <td>Cellule 5-4</td>
    <td>Cellule 5-5</td>
  </tr>
</table>

</body>
</html>
"""

mail.HTMLBody =html
# Attacher le corps du message au conteneur MIMEMultipart


# To attach a file to the email (optional):
attachment  = r"C:\Users\Paul\Downloads\VBA_Cheatsheet_Zero_To_Mastery_V1.01.pdf"
mail.Attachments.Add(attachment)

mail.Send()
